# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Rastyazheniye

# %%
df = pd.read_csv('/Users/kseniiakirillova/Documents/personal/studies/biomaterials/rastyag.csv', sep=';')
df.head()
# Out:
#      s       mm        n
# 0  0.0 -0.00024 -0.00400
# 1  0.1  0.04463 -0.01884
# 2  0.2  0.09964  0.03520
# 3  0.3  0.14993  0.01516
# 4  0.4  0.19963  0.02583

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %%
x=df['mm'][1:4190].values #4190
y=df['n'][1:4190].values
np.polyfit(x,y,1)
# Out:
# array([ 0.05272745, -0.85594194])

# %%
approx=0.05272745*x-0.85594194

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot(x, approx)
idx = np.argwhere(np.diff(np.sign(y - approx))).flatten()
plt.plot(x[idx], approx[idx], 'ro')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %%
x[idx]
# Out:
# array([ 40.59966,  40.64994,  40.84993,  40.89999,  40.94957,  41.09998,
#         41.15002,  41.19914,  41.24979,  41.39983,  41.44965, 173.35028,
#        173.39963, 173.44934, 173.49985, 174.14973, 174.20004, 174.30014,
#        174.39978, 174.4496 , 174.6503 , 174.6994 , 175.29971, 175.35025])

# %%
y[idx]
# Out:
# array([1.29762, 1.27856, 1.31853, 1.27491, 1.31976, 1.29939, 1.33165,
#        1.28841, 1.32927, 1.29713, 1.33838, 8.28378, 8.29139, 8.27958,
#        8.30338, 8.30075, 8.36384, 8.32184, 8.3458 , 8.33399, 8.3596 ,
#        8.35481, 8.39766, 8.38759])

# %%
x1 = [0,41]
y1 = [0,1.3 ]
np.polyfit(x1,y1,1)
# Out:
# array([ 3.17073171e-02, -7.85046229e-17])

# %%
x2 = [0, 174.2]
y2 = [0, 8.36]
np.polyfit(x2,y2,1)
# Out:
# array([0.04799082, 0.        ])

# %%
line1 = 0.0317*x
line2 = 0.047991*x

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot(x, approx, label='linear approximation')
idx = np.argwhere(np.diff(np.sign(y - approx))).flatten()
plt.plot(x[idx], approx[idx], 'ro')
plt.plot(x, line1, label='1', linestyle=':')
plt.plot(x, line2, label='2', linestyle=':', color='r')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %% [markdown]
# # lab rezina odnoosnoye 1

# %%
df = pd.read_csv('/Users/kseniiakirillova/Documents/personal/studies/biomaterials/1-1/1osnoe/2019-03-23_1-strength.is_tens_RawData/Specimen_RawData_1.csv', sep=';')
df.head()
# Out:
#      s       mm        n
# 0  0.0  0.00000  0.01735
# 1  0.1  0.15512  0.02025
# 2  0.2  0.33209  0.01360
# 3  0.3  0.49985  0.03803
# 4  0.4  0.66666  0.01643

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %%
df['mm'] = df['mm']/12
df['n'] = df['n']/(2*0.526)
np.amax(df['n'])
# Out:
# 14.219363117870722

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
plt.xlabel('deformation, %')
plt.ylabel('tension, MPa')
plt.grid(True)

# %%
x=df['mm'][420:960].values #4190
y=df['n'][420:960].values
np.polyfit(x,y,1)
# Out:
# array([ 0.71079999, -1.07193619])

# %%
approx=0.710799*x-1.07193

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot(x, approx)
idx = np.argwhere(np.diff(np.sign(y - approx))).flatten()
plt.plot(x[idx], approx[idx], 'ro')
plt.legend()
plt.xlabel('deformation')
plt.ylabel('tension, MPa')
plt.grid(True)

# %%
x[idx]
# Out:
# array([ 6.90280583,  6.9166675 ,  6.9722025 ,  6.98609417,  7.01388667,
#         7.0277575 ,  7.04165833,  7.05552   ,  7.111075  ,  7.12498583,
#         7.13886833,  7.15275833,  7.18056083,  7.20832417,  7.222215  ,
#         7.25000667,  7.26387833,  7.33331583,  7.3610775 ,  7.3750175 ,
#         7.40275167,  7.41666167,  7.43053333,  7.5277525 ,  7.54165333,
#         7.666645  ,  7.68055583,  7.76386333,  7.777775  ,  7.79167583,
#         7.80554583,  7.91668667,  7.93053833,  8.20831333,  8.22222417,
#         8.27776833,  8.29167083,  8.3749775 ,  8.40278083,  8.47219667,
#         8.49999833,  9.12498417,  9.13885667,  9.81943667,  9.8333375 ,
#        11.500015  , 11.5138575 , 11.83332583, 11.84717833, 11.94444667,
#        11.95832667, 12.04166417, 12.05554667, 12.1805575 , 12.22219083,
#        12.24998333, 12.26390417, 12.27775583, 12.30553833, 12.31942083])

# %%
y[idx]
# Out:
# array([3.85442015, 3.83551331, 3.88659696, 3.87604563, 3.94793726,
#        3.92042776, 3.95019011, 3.93749049, 3.98328897, 3.97737643,
#        4.02228137, 4.01189163, 4.03971483, 4.04941065, 4.07585551,
#        4.06777567, 4.10786122, 4.13273764, 4.1604943 , 4.16072243,
#        4.19435361, 4.18825095, 4.21489544, 4.26696768, 4.29855513,
#        4.35360266, 4.41103612, 4.42436312, 4.46079848, 4.44339354,
#        4.48695817, 4.52562738, 4.57164449, 4.75007605, 4.78218631,
#        4.75480989, 4.82623574, 4.84535171, 4.90244297, 4.93093156,
#        4.97044677, 5.37847909, 5.42795627, 5.86269011, 5.92081749,
#        7.05259506, 7.1175    , 7.27363118, 7.35058935, 7.40271863,
#        7.43964829, 7.47360266, 7.49862167, 7.56891635, 7.64589354,
#        7.6315019 , 7.64648289, 7.64170152, 7.70614068, 7.6713403 ])

# %%
x1 = [0,6.9028]
y1 = [0,3.854]
np.polyfit(x1,y1,1)
# Out:
# array([0.55832416, 0.        ])

# %%
x2 = [0, 12.3194]
y2 = [0, 7.671]
np.polyfit(x2,y2,1)
# Out:
# array([6.22676429e-01, 6.28036983e-16])

# %%
xline=df['mm'][:1000].values
line1 = 0.5583*xline
line2 = 0.6226764*xline

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot(x, approx, label='linear approximation')
idx = np.argwhere(np.diff(np.sign(y - approx))).flatten()
plt.plot(x[idx], approx[idx], 'ro')
plt.plot(xline, line1, label='1', linestyle=':')
plt.plot(xline, line2, label='2', linestyle=':', color='r')
plt.legend()
plt.xlabel('deformation')
plt.ylabel('tension, MPa')
plt.grid(True)

# %% [markdown]
# # lab rezina odnoosnoye 2

# %%
df = pd.read_csv('/Users/kseniiakirillova/Documents/personal/studies/biomaterials/1-1/1osnoe/2019-03-23_1-strength.is_tens_RawData/Specimen_RawData_2.csv', sep=';')
df.head()
# Out:
#      s       mm        n
# 0  0.0  0.00000  0.03170
# 1  0.1  0.15453  0.01215
# 2  0.2  0.33280  0.02502
# 3  0.3  0.49985  0.04663
# 4  0.4  0.66631  0.03899

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %%
df['mm'] = df['mm']/12
df['n'] = df['n']/(2*0.526)
np.amax(df['n'])
# Out:
# 17.86937262357414

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %%
x=df['mm'][365:900].values #4190
y=df['n'][365:900].values
np.polyfit(x,y,1)
# Out:
# array([ 0.72070932, -0.92435402])

# %%
approx=0.720709*x-0.924354

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot(x, approx)
idx = np.argwhere(np.diff(np.sign(y - approx))).flatten()
plt.plot(x[idx], approx[idx], 'ro')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %%
x[idx]
# Out:
# array([ 6.06945167,  6.08331333,  6.24999833,  6.2778    ,  6.31944417,
#         6.333335  ,  6.3611075 ,  6.38885083,  6.40279167,  6.41667333,
#         6.43053333,  6.4722075 ,  6.48612833,  6.51388083,  6.55551583,
#         6.59718917,  6.61114   ,  6.68056583,  6.69443667,  6.84724083,
#         6.8611025 , 10.75      , 10.76388917, 10.875     , 10.90280167,
#        10.98610083, 11.00001167, 11.02778333, 11.041655  , 11.08331083,
#        11.12498333, 11.15275583, 11.23612333, 11.24999333, 11.29167917,
#        11.30555   ])

# %%
y[idx]
# Out:
# array([3.47558935, 3.45408745, 3.58276616, 3.58163498, 3.64087452,
#        3.63761407, 3.67671103, 3.66723384, 3.69271863, 3.6861597 ,
#        3.71479087, 3.73380228, 3.75752852, 3.76419202, 3.80639734,
#        3.82152091, 3.85484791, 3.8691635 , 3.90288973, 3.96419202,
#        4.02113118, 6.81251901, 6.83355513, 6.91010456, 6.93976236,
#        6.96762357, 7.02277567, 7.02098859, 7.08307985, 7.05384981,
#        7.10764259, 7.11171103, 7.19587452, 7.1744962 , 7.24903992,
#        7.20752852])

# %%
x1 = [0,6.06945]
y1 = [0,3.475]
np.polyfit(x1,y1,1)
# Out:
# array([0.57253952, 0.        ])

# %%
x2 = [0, 11.305]
y2 = [0, 7.2075]
np.polyfit(x2,y2,1)
# Out:
# array([0.63754976, 0.        ])

# %%
xline=df['mm'][:1000].values
line1 = 0.57253*xline
line2 = 0.63754*xline

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot(x, approx, label='linear approximation')
idx = np.argwhere(np.diff(np.sign(y - approx))).flatten()
plt.plot(x[idx], approx[idx], 'ro')
plt.plot(xline, line1, label='1', linestyle=':')
plt.plot(xline, line2, label='2', linestyle=':', color='r')
plt.legend()
plt.xlabel('deformation')
plt.ylabel('tension, MPa')
plt.grid(True)

# %% [markdown]
# # lab rezina odnoosnoye 3

# %%
df = pd.read_csv('/Users/kseniiakirillova/Documents/personal/studies/biomaterials/1-1/1osnoe/2019-03-23_1-strength.is_tens_RawData/Specimen_RawData_3.csv', sep=';')
df.head()
# Out:
#      s       mm        n
# 0  0.0  0.00000  0.01247
# 1  0.1  0.15477  0.02082
# 2  0.2  0.33268  0.00789
# 3  0.3  0.49985  0.02851
# 4  0.4  0.66701  0.03869

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %%
df['mm'] = df['mm']/12
df['n'] = df['n']/(2*0.526)
np.amax(df['n'])
# Out:
# 17.07102661596958

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %%
x = df['mm'][(df['mm'] > 5) & (df['mm'] < 12.5)].values 
y= df['n'][(df['mm'] > 5) & (df['mm'] < 12.5)].values
np.polyfit(x,y,1)
# Out:
# array([ 0.72181327, -1.04548092])

# %%
approx=0.721813*x-1.04548

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot(x, approx)
idx = np.argwhere(np.diff(np.sign(y - approx))).flatten()
plt.plot(x[idx], approx[idx], 'ro')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %%
x[idx]
# Out:
# array([ 5.90280667,  5.91662833,  6.0833425 ,  6.09724417,  6.11109583,
#         6.12501583,  6.20834417,  6.25000833,  6.27777   ,  6.30558167,
#         6.31943417,  6.37499833,  6.38888   ,  6.45830667,  6.47226667,
#         8.86109083,  8.8749925 ,  8.97222167,  8.9860825 ,  9.00004333,
#         9.01389417,  9.06942083,  9.13889583,  9.16666833,  9.18056917,
#         9.23611417,  9.30556083,  9.31943167,  9.33331333,  9.7638825 ,
#         9.7777825 ,  9.8611    ,  9.87502   , 10.01392333, 10.02775583,
#        10.0416475 , 10.0555775 , 10.1111225 , 10.13888583, 10.15278667,
#        10.19442083, 10.20833083, 10.2222325 , 10.23609333, 10.31944167,
#        10.33334167, 10.34720417, 10.361095  , 10.37498667, 10.3888875 ,
#        10.4167    , 10.43055083, 10.4583425 , 10.50000667, 10.52779083,
#        10.54164   , 10.55558167, 10.58334333, 10.597225  , 10.61111667,
#        10.6250175 , 10.63887917, 10.66664417, 10.6805925 , 10.694415  ,
# ...

# %%
y[idx]
# Out:
# array([3.26394487, 3.22423954, 3.36324144, 3.35271863, 3.37845057,
#        3.35603612, 3.43823194, 3.45788973, 3.49268061, 3.49205323,
#        3.52055133, 3.55547529, 3.57772814, 3.59807985, 3.63093156,
#        5.33654943, 5.37202471, 5.41071293, 5.45979087, 5.41576996,
#        5.46746198, 5.48586502, 5.5566635 , 5.5626711 , 5.60377376,
#        5.61541825, 5.67358365, 5.67564639, 5.70238593, 5.97263308,
#        6.01603612, 6.04592205, 6.08509506, 6.16901141, 6.20286122,
#        6.19869772, 6.22624525, 6.24576046, 6.28372624, 6.27388783,
#        6.32435361, 6.31268061, 6.35037072, 6.33478137, 6.4233365 ,
#        6.4064924 , 6.43761407, 6.42288973, 6.45655894, 6.4489924 ,
#        6.47920152, 6.47419202, 6.5154943 , 6.51106464, 6.57645437,
#        6.55923004, 6.57752852, 6.56297529, 6.60730989, 6.60965779,
#        6.65355513, 6.6308365 , 6.66902091, 6.64581749, 6.690827  ,
#        6.66606464, 6.71181559, 6.68592205, 6.75322243, 6.73113118,
# ...

# %%
x1 = [0,5.902]
y1 = [0,3.263]
np.polyfit(x1,y1,1)
# Out:
# array([0.55286344, 0.        ])

# %%
x2 = [0, 11.708]
y2 = [0, 7.3973]
np.polyfit(x2,y2,1)
# Out:
# array([0.63181585, 0.        ])

# %%
xline=df['mm'][:1000].values
line1 = 0.552863*xline
line2 = 0.63181585*xline

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot(x, approx, label='linear approximation')
idx = np.argwhere(np.diff(np.sign(y - approx))).flatten()
plt.plot(x[idx], approx[idx], 'ro')
plt.plot(xline, line1, label='1', linestyle=':')
plt.plot(xline, line2, label='2', linestyle=':', color='r')
plt.legend()
plt.xlabel('deformation')
plt.ylabel('tension, MPa')
plt.grid(True)

# %% [markdown]
# # Lab rezina razdir tolschina 1

# %%
df = pd.read_csv('/Users/kseniiakirillova/Documents/personal/studies/biomaterials/1-1/tolshina/2019-03-23_1-thick-.is_tens_RawData/Specimen_RawData_1.csv', sep=';')
df.head()
# Out:
#      s       mm        n
# 0  0.0  0.00000  0.04516
# 1  0.1  0.07497  0.00322
# 2  0.2  0.16575  0.04955
# 3  0.3  0.24969  0.03213
# 4  0.4  0.33339  0.02501

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
#plt.title('semilogx')
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %%
x=df['mm'][300:3020].values
y=df['n'][300:3020].values
med = np.median(y)
med
# Out:
# 1.9546649999999999

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot((x[1],x[-1]), (med,med), linestyle=':', linewidth=3.0)
plt.legend()
#plt.title('semilogx')
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %% [markdown]
# # Lab rezina razdir tolschina 2

# %%
df = pd.read_csv('/Users/kseniiakirillova/Documents/personal/studies/biomaterials/1-1/tolshina/2019-03-23_1-thick-.is_tens_RawData/Specimen_RawData_2.csv', sep=';')
df.head()
# Out:
#      s       mm        n
# 0  0.0  0.00000  0.01676
# 1  0.1  0.08134  0.03470
# 2  0.2  0.17106  0.02733
# 3  0.3  0.25488  0.00230
# 4  0.4  0.33858  0.03208

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %%
x=df['mm'][200:1780].values
y=df['n'][200:1780].values
med = np.median(y)
med
# Out:
# 1.7046800000000002

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot((x[1],x[-1]), (med,med), linestyle=':', linewidth=3.0)
plt.legend()
#plt.title('semilogx')
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %% [markdown]
# # Lab rezina razdir tolschina 3

# %%
df = pd.read_csv('/Users/kseniiakirillova/Documents/personal/studies/biomaterials/1-1/tolshina/2019-03-23_1-thick-.is_tens_RawData/Specimen_RawData_3.csv', sep=';')
df.head()
# Out:
#      s       mm        n
# 0  0.0  0.00000  0.01674
# 1  0.1  0.07520  0.03238
# 2  0.2  0.16587  0.03766
# 3  0.3  0.24957  0.05414
# 4  0.4  0.33351  0.01576

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %%
x=df['mm'][243:1500].values
y=df['n'][243:1500].values
med = np.median(y)
med
# Out:
# 1.6642

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot((x[1],x[-1]), (med,med), linestyle=':', linewidth=3.0)
plt.legend()
#plt.title('semilogx')
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %% [markdown]
# # Lab rezina razdir shirina 1

# %%
df = pd.read_csv('/Users/kseniiakirillova/Documents/personal/studies/biomaterials/1-1/shirina/2019-03-23_1-shirina-_1.is_tens_RawData/Specimen_RawData_1.csv', sep=';')
df.head()
# Out:
#      s       mm        n
# 0  0.0  0.00024  0.01521
# 1  0.1  0.01062  0.02151
# 2  0.2  0.03660  0.04771
# 3  0.3  0.05466  0.01525
# 4  0.4  0.07154  0.04377

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %%
x=df['mm'][509:].values
y=df['n'][509:].values
med = np.median(y)
med
# Out:
# 1.47933

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot((x[1],x[-1]), (med,med), linestyle=':', linewidth=3.0, color='r')
plt.legend()
#plt.title('semilogx')
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %% [markdown]
# # Lab rezina razdir shirina 2

# %%
df = pd.read_csv('/Users/kseniiakirillova/Documents/personal/studies/biomaterials/1-1/shirina/2019-03-23_1-shirina-_1.is_tens_RawData/Specimen_RawData_2.csv', sep=';')
df.head()
# Out:
#      s       mm        n
# 0  0.0  0.00024  0.01173
# 1  0.1  0.03258  0.00172
# 2  0.2  0.06965  0.02246
# 3  0.3  0.10283  0.05283
# 4  0.4  0.13659  0.07743

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %%
x=df['mm'][230:].values
y=df['n'][230:].values
med = np.median(y)
med
# Out:
# 1.77551

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot((x[1],x[-1]), (med,med), linestyle=':', linewidth=3.0, color='r')

plt.legend()
#plt.title('semilogx')
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %% [markdown]
# # Lab rezina razdir shirina 3

# %%
df = pd.read_csv('/Users/kseniiakirillova/Documents/personal/studies/biomaterials/1-1/shirina/2019-03-23_1-shirina-_1.is_tens_RawData/Specimen_RawData_3.csv', sep=';')
df.head()
# Out:
#      s       mm        n
# 0  0.0  0.00000  0.02448
# 1  0.1  0.02668  0.02512
# 2  0.2  0.06635  0.01647
# 3  0.3  0.09952  0.01302
# 4  0.4  0.13328  0.05264

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %%
x=df['mm'][137:2400].values
y=df['n'][137:2400].values
med = np.median(y)
med
# Out:
# 0.72607

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot((x[1],x[-1]), (med,med), linestyle=':', linewidth=3.0, color='r')

plt.legend()
#plt.title('semilogx')
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %% [markdown]
# # laba kurica odnoosnoye 3

# %%
df = pd.read_csv('/Users/kseniiakirillova/Documents/personal/studies/biomaterials/2/odnoosnoe/Specimen_RawData_3.csv', sep=';')
df.head()
# Out:
#       s       mm        n
# 0  24.1  4.01649  0.03455
# 1  24.2  4.03360  0.04071
# 2  24.3  4.05013  0.02682
# 3  24.4  4.06607  0.05568
# 4  24.5  4.08307  0.03579

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %%
df['mm'] = (df['mm']-df['mm'][1])/12
df['n'] = (df['n']-df['n'][1])/(2*1.96)
np.amax(df['n'])
# Out:
# 1.1189897959183674

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %%
x=df['mm'][122:270].values #4190
y=df['n'][122:270].values
np.polyfit(x,y,1)
# Out:
# array([ 2.94005849, -0.35081507])

# %%
approx=2.94*x-0.3508

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot(x, approx)
idx = np.argwhere(np.diff(np.sign(y - approx))).flatten()
plt.plot(x[idx], approx[idx], 'ro')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %%
x[idx]
# Out:
# array([0.18332083, 0.18467833, 0.1874925 , 0.1901975 , 0.1971825 ,
#        0.19860917, 0.19995667, 0.20132417, 0.20276083, 0.2041675 ,
#        0.205515  , 0.2138775 , 0.215265  , 0.24164   , 0.244415  ,
#        0.2624675 , 0.26386417, 0.26662833, 0.26940333, 0.27358417,
#        0.2791325 , 0.28052   , 0.28330417, 0.28609833, 0.29025917,
#        0.29441083, 0.29855333, 0.29995   , 0.30550833, 0.306935  ,
#        0.30965   , 0.31108667, 0.31250333, 0.31385083, 0.32077667,
#        0.32222333, 0.32493833, 0.32776167, 0.33192333, 0.33334   ,
#        0.3347075 , 0.336045  , 0.34024583, 0.34160417, 0.34444667,
#        0.345775  , 0.35135333, 0.35273083, 0.35415667, 0.35553417,
#        0.36244083])

# %%
y[idx]
# Out:
# array([0.1954898 , 0.1911199 , 0.20529082, 0.20788776, 0.22932653,
#        0.22815306, 0.23939031, 0.23611224, 0.24646429, 0.24401786,
#        0.25518878, 0.27577041, 0.28240051, 0.35523214, 0.36946173,
#        0.41788265, 0.42555102, 0.42946684, 0.4468648 , 0.44468112,
#        0.472875  , 0.47093367, 0.48765306, 0.48696684, 0.50359949,
#        0.51332398, 0.52840816, 0.52721684, 0.55435714, 0.54828316,
#        0.56109949, 0.56089286, 0.57347194, 0.56964031, 0.59809439,
#        0.59542602, 0.6054898 , 0.61122194, 0.63014541, 0.62859184,
#        0.63987755, 0.63410204, 0.65283929, 0.65351531, 0.67561735,
#        0.66555867, 0.69081888, 0.68310969, 0.69313265, 0.69370918,
#        0.71955612])

# %%
x1 = [0,0.183]
y1 = [0,0.195489]
np.polyfit(x1,y1,1)
# Out:
# array([1.0682459, 0.       ])

# %%
x2 = [0, 0.3624]
y2 = [0, 0.7195]
np.polyfit(x2,y2,1)
# Out:
# array([1.98537528, 0.        ])

# %%
xline=df['mm'][:300].values #4190
line1 = 1.06824*xline
line2 = 1.98537*xline

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot(x, approx, label='linear approximation')
idx = np.argwhere(np.diff(np.sign(y - approx))).flatten()
plt.plot(x[idx], approx[idx], 'ro')
plt.plot(xline, line1, label='1', linestyle=':')
plt.plot(xline, line2, label='2', linestyle=':', color='r')
plt.legend()
plt.xlabel('deformation')
plt.ylabel('tension, MPa')
plt.grid(True)

# %% [markdown]
# # laba kurica odnoosnoye 2

# %%
df = pd.read_csv('/Users/kseniiakirillova/Documents/personal/studies/biomaterials/2/odnoosnoe/Specimen_RawData_2.csv', sep=';')
df.head()
# Out:
#       s       mm        n
# 0  18.0  3.00038  0.04989
# 1  18.1  3.01679  0.03432
# 2  18.2  3.03320  0.06697
# 3  18.3  3.05008  0.04318
# 4  18.4  3.06685  0.06881

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %%
df['mm'] = (df['mm']-df['mm'][1])/12
df['n'] = (df['n']-df['n'][1])/(2*1.6)
np.amax(df['n'])
# Out:
# 0.90339375

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %%
x=df['mm'][250:400].values #4190
y=df['n'][250:400].values
np.polyfit(x,y,1)
# Out:
# array([ 2.8967305 , -0.69215404])

# %%
approx= 2.8967*x-0.6921

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot(x, approx)
idx = np.argwhere(np.diff(np.sign(y - approx))).flatten()
plt.plot(x[idx], approx[idx], 'ro')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %%
x[idx]
# Out:
# array([0.36250917, 0.36389667, 0.36805833, 0.4069475 , 0.40833417,
#        0.41944167, 0.42082917, 0.44164583, 0.44303333, 0.447185  ,
#        0.44859167, 0.45556667, 0.45694417, 0.45973833, 0.461125  ,
#        0.4624925 , 0.46385   , 0.46527667, 0.46667333, 0.47225167,
#        0.47357   , 0.47496667, 0.47641333, 0.48334917, 0.4846675 ,
#        0.48610333, 0.48752   , 0.490245  , 0.49168167, 0.49307833,
#        0.49439667, 0.49579417, 0.5013725 , 0.50279833, 0.5110825 ,
#        0.51250833, 0.53332583, 0.5347425 , 0.54029083, 0.5444525 ,
#        0.54584   ])

# %%
y[idx]
# Out:
# array([0.36349375, 0.35762188, 0.386175  , 0.48339687, 0.49097813,
#        0.51725938, 0.53106562, 0.5860625 , 0.59345   , 0.59977812,
#        0.61153437, 0.6161125 , 0.63725   , 0.63426875, 0.64654375,
#        0.64271562, 0.65435625, 0.65149375, 0.66091875, 0.673325  ,
#        0.68011562, 0.67787812, 0.69249375, 0.70581875, 0.71683438,
#        0.71029062, 0.73249375, 0.72749687, 0.73561562, 0.73449062,
#        0.74445625, 0.73766562, 0.76760937, 0.75811875, 0.8019625 ,
#        0.79175   , 0.85890937, 0.85398125, 0.87408438, 0.87913437,
#        0.89109375])

# %%
x1 = [0,0.362]
y1 = [0,0.36349]
np.polyfit(x1,y1,1)
# Out:
# array([1.00411602e+00, 3.92523115e-17])

# %%
x2 = [0, 0.54]
y2 = [0, 0.891093]
np.polyfit(x2,y2,1)
# Out:
# array([1.65017222, 0.        ])

# %%
xline=df['mm'][:400].values #4190
line1 = 1.00411*xline
line2 = 1.65017*xline

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot(x, approx, label='linear approximation')
idx = np.argwhere(np.diff(np.sign(y - approx))).flatten()
plt.plot(x[idx], approx[idx], 'ro')
plt.plot(xline, line1, label='1', linestyle=':')
plt.plot(xline, line2, label='2', linestyle=':', color='r')
plt.legend()
plt.xlabel('deformation')
plt.ylabel('tension, MPa')
plt.grid(True)

# %% [markdown]
# # laba kurica odnoosnoye 1

# %%
df = pd.read_csv('/Users/kseniiakirillova/Documents/personal/studies/biomaterials/2/odnoosnoe/Specimen_RawData_1.csv', sep=';')
df.head()
# Out:
#       s       mm        n
# 0  12.1  2.01686  0.06170
# 1  12.2  2.03362  0.03154
# 2  12.3  2.05003  0.08229
# 3  12.4  2.06656  0.08845
# 4  12.5  2.08333  0.07446

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %%
df['mm'] = (df['mm']-df['mm'][1])/12
df['n'] = (df['n']-df['n'][1])/(2*1.47)
np.amax(df['n'])
# Out:
# 1.2652517006802722

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %%
x = df['mm'][(df['mm'] > 0.2) & (df['mm'] < 0.4)].values 
y= df['n'][(df['mm'] > 0.2) & (df['mm'] < 0.4)].values
np.polyfit(x,y,1)
# Out:
# array([ 3.6949925 , -0.44685026])

# %%
approx=3.6949*x-0.44685

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot(x, approx)
idx = np.argwhere(np.diff(np.sign(y - approx))).flatten()
plt.plot(x[idx], approx[idx], 'ro')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %%
x[idx]
# Out:
# array([0.21803917, 0.21945583, 0.22772   , 0.22916583, 0.23474417,
#        0.23613083, 0.23743917, 0.23886583, 0.2402825 , 0.24165   ,
#        0.24299833, 0.25694833, 0.25966333, 0.277775  , 0.2791325 ,
#        0.3152675 , 0.316645  , 0.32080667, 0.32361   , 0.3249875 ,
#        0.32777167, 0.32914917, 0.33051667, 0.3347175 , 0.34164333,
#        0.34306   , 0.3444475 , 0.345795  , 0.35690167, 0.35831833,
#        0.37502333, 0.37639083, 0.38058167, 0.38195917, 0.38611083,
#        0.38745833, 0.3930175 , 0.39441417, 0.39583083, 0.39856583])

# %%
y[idx]
# Out:
# array([0.36063946, 0.3622483 , 0.39551361, 0.39058844, 0.42914286,
#        0.4244898 , 0.43635714, 0.42421429, 0.44118367, 0.43758163,
#        0.45268027, 0.49188435, 0.51293878, 0.56860204, 0.58861224,
#        0.71239116, 0.72363265, 0.72603741, 0.74918367, 0.75194218,
#        0.76668027, 0.76352721, 0.77468367, 0.78744218, 0.81709184,
#        0.81897619, 0.83311565, 0.83079932, 0.87322109, 0.8770034 ,
#        0.93892177, 0.94341156, 0.96002381, 0.96304422, 0.98222789,
#        0.97932313, 1.01156803, 1.00880612, 1.02114626, 1.02401361])

# %%
x1 = [0,0.21803]
y1 = [0,0.36063]
np.polyfit(x1,y1,1)
# Out:
# array([1.65403844, 0.        ])

# %%
x2 = [0, 0.398565]
y2 = [0, 1.024013]
np.polyfit(x2,y2,1)
# Out:
# array([2.56924968, 0.        ])

# %%
xline=df['mm'][:350].values #4190
line1 = 1.65403*xline
line2 = 2.56924*xline

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot(x, approx, label='linear approximation')
idx = np.argwhere(np.diff(np.sign(y - approx))).flatten()
plt.plot(x[idx], approx[idx], 'ro')
plt.plot(xline, line1, label='1', linestyle=':')
plt.plot(xline, line2, label='2', linestyle=':', color='r')
plt.legend()
plt.xlabel('deformation')
plt.ylabel('tension, MPa')
plt.grid(True)

# %% [markdown]
# # Lab kurica razdir tolschina 1

# %%
df = pd.read_csv('/Users/kseniiakirillova/Documents/personal/studies/biomaterials/2/tolshina/Specimen_RawData_1.csv', sep=';')
df.head()
# Out:
#      s       mm        n
# 0  0.0  0.00000  0.04503
# 1  0.1  0.00838  0.05384
# 2  0.2  0.03270  0.03992
# 3  0.3  0.04982  0.00209
# 4  0.4  0.06611  0.04111

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %%
x = df['mm'][(df['mm'] > 10) & (df['mm'] < 52)].values 
y= df['n'][(df['mm'] > 10) & (df['mm'] < 52)].values
med = np.median(y)
med
# Out:
# 0.642725

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot((x[1],x[-1]), (med,med), linestyle=':', linewidth=3.0, label='median')
plt.legend()
#plt.title('semilogx')
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %% [markdown]
# # Lab kurica razdir tolschina 2

# %%
df = pd.read_csv('/Users/kseniiakirillova/Documents/personal/studies/biomaterials/2/tolshina/Specimen_RawData_2.csv', sep=';')
df.head()
# Out:
#      s       mm        n
# 0  0.0  0.00083  0.02311
# 1  0.1  0.05903  0.02645
# 2  0.2  0.11286  0.01235
# 3  0.3  0.16280 -0.00085
# 4  0.4  0.21250  0.02126

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %%
x = df['mm'][(df['mm'] > 10) & (df['mm'] < 43)].values 
y= df['n'][(df['mm'] > 10) & (df['mm'] < 43)].values
med = np.median(y)
med
# Out:
# 0.865335

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot((x[1],x[-1]), (med,med), linestyle=':', linewidth=3.0, label='median')
plt.legend()
#plt.title('semilogx')
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %% [markdown]
# # Lab kurica razdir tolschina 3

# %%
df = pd.read_csv('/Users/kseniiakirillova/Documents/personal/studies/biomaterials/2/tolshina/Specimen_RawData_3.csv', sep=';')
df.head()
# Out:
#      s       mm        n
# 0  0.0  0.00000  0.01168
# 1  0.1  0.04215 -0.00685
# 2  0.2  0.09952 -0.00992
# 3  0.3  0.14993  0.02910
# 4  0.4  0.19963  0.02048

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %%
x = df['mm'][(df['mm'] > 17) & (df['mm'] < 78)].values 
y= df['n'][(df['mm'] > 17) & (df['mm'] < 78)].values
med = np.median(y)
med
# Out:
# 1.280545

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot((x[1],x[-1]), (med,med), linestyle=':', linewidth=3.0, label='median')
plt.legend()
#plt.title('semilogx')
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %% [markdown]
# mediann should be only on the area where it was calculated

# %% [markdown]
# # laba protez 1

# %%
df = pd.read_csv('/Users/kseniiakirillova/Documents/personal/studies/biomaterials/4/2019-03-23_protezi/Specimen_RawData_1.csv', sep=';')
df.head()
# Out:
#      s       mm        n
# 0  0.0  1.07785  0.01731
# 1  0.1  1.08422  0.07051
# 2  0.2  1.10795  0.04065
# 3  0.3  1.12731  0.06582
# 4  0.4  1.14396  0.05475

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %%
df['mm'] = (df['mm']-df['mm'][1])/12
df['n'] = df['n']/(2*0.42)
np.amax(df['n'])
# Out:
# 34.31305952380953

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %%
x=df['mm'][350:530].values #4190
y=df['n'][350:530].values
np.polyfit(x,y,1)
# Out:
# array([ 69.8655893 , -26.97639635])

# %%
approx=69.865589*x-26.976

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot(x, approx)
idx = np.argwhere(np.diff(np.sign(y - approx))).flatten()
plt.plot(x[idx], approx[idx], 'ro')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %%
x[idx]
# Out:
# array([0.55919   , 0.56058667, 0.56472833, 0.6786625 , 0.68002   ,
#        0.6813875 , 0.68280417, 0.68418083, 0.68556833, 0.686975  ,
#        0.69111667, 0.69252417])

# %%
y[idx]
# Out:
# array([12.02372619, 12.19682143, 12.47430952, 20.52804762, 20.50069048,
#        20.63192857, 20.72667857, 20.84711905, 20.88286905, 21.02110714,
#        21.19522619, 21.41340476])

# %%
x1 = [0,0.559]
y1 = [0,12.023]
np.polyfit(x1,y1,1)
# Out:
# array([2.15080501e+01, 6.28036983e-16])

# %%
x2 = [0, 0.692]
y2 = [0, 21.41]
np.polyfit(x2,y2,1)
# Out:
# array([30.93930636,  0.        ])

# %%
xline=df['mm'][:550].values #4190
line1 = 21.50*xline
line2 = 30.939*xline

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot(x, approx, label='linear approximation')
idx = np.argwhere(np.diff(np.sign(y - approx))).flatten()
plt.plot(x[idx], approx[idx], 'ro')
plt.plot(xline, line1, label='1', linestyle=':')
plt.plot(xline, line2, label='2', linestyle=':', color='r')
plt.legend()
plt.xlabel('deformation')
plt.ylabel('tension, MPa')
plt.grid(True)

# %% [markdown]
# # laba protez 2

# %%
df = pd.read_csv('/Users/kseniiakirillova/Documents/personal/studies/biomaterials/4/2019-03-23_protezi/Specimen_RawData_2.csv', sep=';')
df.head()
# Out:
#      s       mm        n
# 0  0.0  0.00000  0.03234
# 1  0.1  0.00874  0.02184
# 2  0.2  0.03412 -0.01280
# 3  0.3  0.05242  0.00058
# 4  0.4  0.06918  0.00184

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %%
df['mm'] = (df['mm']-df['mm'][1])/12
df['n'] = df['n']/(2*0.42)
np.amax(df['n'])
# Out:
# 31.247678571428573

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %%
x=df['mm'][360:600].values #4190
y=df['n'][360:600].values
np.polyfit(x,y,1)
# Out:
# array([ 57.08311769, -22.45987576])

# %%
approx=57.0831*x-22.4598757

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot(x, approx)
idx = np.argwhere(np.diff(np.sign(y - approx))).flatten()
plt.plot(x[idx], approx[idx], 'ro')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %%
x[idx]
# Out:
# array([0.57312   , 0.77447333])

# %%
y[idx]
# Out:
# array([10.25052381, 21.77658333])

# %%
x1 = [0,0.57]
y1 = [0,10.250]
np.polyfit(x1,y1,1)
# Out:
# array([17.98245614,  0.        ])

# %%
x2 = [0, 0.774]
y2 = [0, 21.776]
np.polyfit(x2,y2,1)
# Out:
# array([2.81343669e+01, 1.25607397e-15])

# %%
xline=df['mm'][:650].values #4190
line1 = 17.98*xline
line2 = 28.13*xline

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot(x, approx, label='linear approximation')
idx = np.argwhere(np.diff(np.sign(y - approx))).flatten()
plt.plot(x[idx], approx[idx], 'ro')
plt.plot(xline, line1, label='1', linestyle=':')
plt.plot(xline, line2, label='2', linestyle=':', color='r')
plt.legend()
plt.xlabel('deformation')
plt.ylabel('tension, MPa')
plt.grid(True)

# %% [markdown]
# # laba protez 3

# %%
df = pd.read_csv('/Users/kseniiakirillova/Documents/personal/studies/biomaterials/4/2019-03-23_protezi/Specimen_RawData_3.csv', sep=';')
df.head()
# Out:
#      s       mm        n
# 0  0.0  0.00000  0.04304
# 1  0.1  0.00602  0.03330
# 2  0.2  0.02975  0.03237
# 3  0.3  0.04947  0.02664
# 4  0.4  0.06623 -0.00158

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %%
df['mm'] = (df['mm']-df['mm'][1])/12
df['n'] = df['n']/(2*0.42)
np.amax(df['n'])
# Out:
# 31.281178571428576

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %%
x=df['mm'][420:660].values #4190
y=df['n'][420:660].values
np.polyfit(x,y,1)
# Out:
# array([ 54.38037252, -25.17195523])

# %%
approx=54.3803*x-25.1719

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot(x, approx)
idx = np.argwhere(np.diff(np.sign(y - approx))).flatten()
plt.plot(x[idx], approx[idx], 'ro')
plt.legend()
#plt.title('semilogx')
plt.grid(True)

# %%
x[idx]
# Out:
# array([0.68700417, 0.68839167, 0.69116583, 0.69673417, 0.69810167,
#        0.70091583, 0.70226333, 0.85781167, 0.85920833, 0.860615  ])

# %%
y[idx]
# Out:
# array([12.18458333, 12.28752381, 12.37791667, 12.75030952, 12.77247619,
#        12.98064286, 13.01060714, 21.49028571, 21.54955952, 21.65359524])

# %%
x1 = [0,0.687]
y1 = [0,12.184]
np.polyfit(x1,y1,1)
# Out:
# array([1.77350801e+01, 1.25607397e-15])

# %%
x2 = [0, 0.8606]
y2 = [0, 21.65]
np.polyfit(x2,y2,1)
# Out:
# array([2.51568673e+01, 1.25607397e-15])

# %%
xline=df['mm'][:680].values #4190
line1 = 17.73*xline
line2 = 25.15*xline

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot(x, approx, label='linear approximation')
idx = np.argwhere(np.diff(np.sign(y - approx))).flatten()
plt.plot(x[idx], approx[idx], 'ro')
plt.plot(xline, line1, label='1', linestyle=':')
plt.plot(xline, line2, label='2', linestyle=':', color='r')
plt.legend()
plt.xlabel('deformation')
plt.ylabel('tension, MPa')
plt.grid(True)

# %% [markdown]
# # laba bint prodolnoye 1

# %%
df = pd.read_csv('/Users/kseniiakirillova/Documents/personal/studies/biomaterials/3/2019-03-23_prod.is_tens_RawData/Specimen_RawData_1.csv', sep=';')
df.head()
# Out:
#       s       mm        n
# 0  10.8  1.79999  0.09918
# 1  10.9  1.81676  0.12427
# 2  11.0  1.83305  0.10753
# 3  11.1  1.84969  0.12131
# 4  11.2  1.86681  0.13692

# %%
df['mm'] = (df['mm']-df['mm'][1])
df['n'] = (df['n']-df['n'][1])

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %%
fmax = np.amax(df['n'])
fmax
# Out:
# 23.30547

# %%
emax = df['mm'][df['n'] == fmax]/19.4
emax
# Out:
# 291    0.249134
# Name: mm, dtype: float64

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot(df['mm'][df['n'] == fmax], fmax, 'ro')
plt.legend()
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %% [markdown]
# # laba bint prodolnoye 2

# %%
df = pd.read_csv('/Users/kseniiakirillova/Documents/personal/studies/biomaterials/3/2019-03-23_prod.is_tens_RawData/Specimen_RawData_2.csv', sep=';')
df.head()
# Out:
#      s       mm        n
# 0  0.0  0.00000  0.01605
# 1  0.1  0.00649  0.03786
# 2  0.2  0.03152  0.04725
# 3  0.3  0.05041  0.05477
# 4  0.4  0.06741  0.02651

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %%
fmax = np.amax(df['n'])
fmax
# Out:
# 16.18654

# %%
emax = df['mm'][df['n'] == fmax]/28.2
emax
# Out:
# 312    0.184447
# Name: mm, dtype: float64

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot(df['mm'][df['n'] == fmax], fmax, 'ro')
plt.legend()
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %% [markdown]
# # laba bint prodolnoye 3

# %%
df = pd.read_csv('/Users/kseniiakirillova/Documents/personal/studies/biomaterials/3/2019-03-23_prod.is_tens_RawData/Specimen_RawData_3.csv', sep=';')
df.head()
# Out:
#      s       mm        n
# 0  4.2  0.70054  0.14250
# 1  4.3  0.71660  0.11699
# 2  4.4  0.73312  0.12698
# 3  4.5  0.75036  0.15062
# 4  4.6  0.76689  0.14159

# %%
df['mm'] = (df['mm']-df['mm'][1])
df['n'] = (df['n']-df['n'][1])

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %%
fmax = np.amax(df['n'])
fmax
# Out:
# 18.80898

# %%
emax = df['mm'][df['n'] == fmax]/26.2
emax
# Out:
# 229    0.145046
# Name: mm, dtype: float64

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot(df['mm'][df['n'] == fmax], fmax, 'ro')
plt.legend()
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %% [markdown]
# # laba bint poperechnoye 1

# %%
df = pd.read_csv('/Users/kseniiakirillova/Documents/personal/studies/biomaterials/3/2019-03-23_poperech.is_tens_RawData/Specimen_RawData_1.csv', sep=';')
df.head()
# Out:
#      s       mm        n
# 0  6.6  1.10004  0.07623
# 1  6.7  1.11692  0.08347
# 2  6.8  1.13333  0.08170
# 3  6.9  1.14986  0.11301
# 4  7.0  1.16674  0.11585

# %%
df['mm'] = (df['mm']-df['mm'][1])
df['n'] = (df['n']-df['n'][1])

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %%
fmax = np.amax(df['n'])
fmax
# Out:
# 8.960749999999999

# %%
emax = df['mm'][df['n'] == fmax]/20
emax
# Out:
# 187    0.154995
# Name: mm, dtype: float64

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot(df['mm'][df['n'] == fmax], fmax, 'ro')
plt.legend()
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %% [markdown]
# # laba bint poperechnoye 2

# %%
df = pd.read_csv('/Users/kseniiakirillova/Documents/personal/studies/biomaterials/3/2019-03-23_poperech.is_tens_RawData/Specimen_RawData_2.csv', sep=';')
df.head()
# Out:
#       s       mm        n
# 0  12.8  2.13267  0.09400
# 1  12.9  2.14991  0.10983
# 2  13.0  2.16703  0.08855
# 3  13.1  2.18308  0.09813
# 4  13.2  2.19973  0.13208

# %%
df['mm'] = (df['mm']-df['mm'][1])
df['n'] = (df['n']-df['n'][1])

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %%
fmax = np.amax(df['n'])
fmax
# Out:
# 14.40344

# %%
emax = df['mm'][df['n'] == fmax]/19.4
emax
# Out:
# 326    0.279207
# Name: mm, dtype: float64

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot(df['mm'][df['n'] == fmax], fmax, 'ro')
plt.legend()
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %% [markdown]
# # laba bint poperechnoye 3

# %%
df = pd.read_csv('/Users/kseniiakirillova/Documents/personal/studies/biomaterials/3/2019-03-23_poperech.is_tens_RawData/Specimen_RawData_3.csv', sep=';')
df.head()
# Out:
#       s       mm        n
# 0  15.0  2.49983  0.14489
# 1  15.1  2.51671  0.12063
# 2  15.2  2.53394  0.11609
# 3  15.3  2.55059  0.14423
# 4  15.4  2.56653  0.13458

# %%
df['mm'] = (df['mm']-df['mm'][1])
df['n'] = (df['n']-df['n'][1])

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.legend()
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)

# %%
fmax = np.amax(df['n'])
fmax
# Out:
# 11.3591

# %%
emax = df['mm'][df['n'] == fmax]/19.3
emax
# Out:
# 316    0.272023
# Name: mm, dtype: float64

# %%
plt.figure(figsize=(15,10))
plt.plot(df['mm'],df['n'], color='g')
plt.plot(df['mm'][df['n'] == fmax], fmax, 'ro')
plt.legend()
plt.xlabel('length, mm')
plt.ylabel('force, N')
plt.grid(True)
